# %% [markdown]
# ## ⛏️ Sun - Preprocessing
#
# Notebook for preprocessing strings previously extracted from the apps.

# %% [markdown]
# #### Imports

# %%
# IMPORT
from   tqdm     import tqdm
import pandas   as pd
import ast
import os

import Sun

# %%
# Initialize TQDM library for Pandas
tqdm.pandas()

# %%
print("⚡ START ⚡\n")

# %% [markdown]
# #### Parameters

# %%
# Ground-Truth Dataset
INPUT_PATH  = "../TMP/1d_SunData.csv"

# Output Path
OUTPUT_PATH = "../TMP/1d_SunDataPreprocessed.csv"

TMP_PATH = "../TMP"
if not os.path.exists(TMP_PATH):
    os.makedirs(TMP_PATH)
    print("📁🆕 Folder created       :", TMP_PATH)
else:
    print("📁✅ Folder already exists:", TMP_PATH)

# %% [markdown]
# ### 1. Load Data

# %%
appsDF = pd.read_csv(INPUT_PATH, index_col=False)
print("#️⃣ Apps: {}".format(appsDF.shape[0]))

appsDF.head(3)

# %% [markdown]
# ### 2. Preprocessing

# %%
print("\n🔨 Loading data as lists")
appsDF['keywords'] = appsDF['keywords'].progress_apply(ast.literal_eval)       

# Pre process the features
Sun.preprocess(appsDF, 'keywords')

# %% [markdown]
# ### 3. Save everything

# %%
# Save the result
appsDF.to_csv(OUTPUT_PATH, index=False)
appsDF.head(3)

# %%
print("\n🔚 END \n")
