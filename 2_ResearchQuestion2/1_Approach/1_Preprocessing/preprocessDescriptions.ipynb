# %% [markdown]
# ## ⛏️ RQ2 New Approach - Preprocess Descriptions
#
# This notebook can be used to preprocess app descriptions using the novel proposed approach.

# %% [markdown]
# #### Imports

# %%
# IMPORT
from   tqdm   import tqdm
import pandas as pd
import os

import customPreprocessing

# %%
# Initialize TQDM library for Pandas
tqdm.pandas()

# %%
print("⚡ START ⚡")

# %% [markdown]
# #### Parameters

# %%
# Where to temporarily store APK Files
APK_PATH    = "../../../0_Data/APKS/"

# Ground-Truth Dataset
INPUT_PATH  = "../../..//0_Data/CSV/0_AndroCatSet.csv"

# Output Path
OUTPUT_PATH = "../TMP/2a_GcataPreprocessedDescriptions.csv"

# %%
# Create folder for output
TMP_PATH = "../TMP"
if not os.path.exists(TMP_PATH):
    os.makedirs(TMP_PATH)
    print("Folder created:", TMP_PATH)
else:
    print("Folder already exists:", TMP_PATH)

# %% [markdown]
# ### 1. Load Data

# %%
appsDF = pd.read_csv(INPUT_PATH, index_col=False)
print("#️⃣ Apps: {}".format(appsDF.shape[0]))

appsDF.head(3)

# %% [markdown]
# ### 2. Preprocess Descriptions

# %%
print("\n⛏️ Preprocessing descriptions")
appsDF['description'] = appsDF['googlePlayDescription'].progress_apply(customPreprocessing.preprocessDescription)

# %% [markdown]
# ### 3.  Save everything

# %%
# Save the result
appsDF = appsDF[['sha256','classID',"description"]]
appsDF.to_csv(OUTPUT_PATH, index=False)
appsDF.head(3)

# %%
print("\n🔚 END")
